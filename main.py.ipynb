# %% [markdown]
# # Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data loading

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  ...  revives  \
# 0         0.00      0              0      0         60  ...        0
# 1        91.47      0              0      0         57  ...        0
# 2        68.00      0              0      0         47  ...        0
# 3        32.90      0              0      0         75  ...        0
# 4       100.00      0              0      0         45  ...        0
#
#    rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# 0        0.0000          0          0.00          0               0
# ...

# %% [markdown]
# # Data Preprocessing

# %%
# Making a deep copy of the dataframe inorder to avoid maing changes in the original
data = df.copy()
data.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  ...  revives  \
# 0         0.00      0              0      0         60  ...        0
# 1        91.47      0              0      0         57  ...        0
# 2        68.00      0              0      0         47  ...        0
# 3        32.90      0              0      0         75  ...        0
# 4       100.00      0              0      0         45  ...        0
#
#    rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# 0        0.0000          0          0.00          0               0
# ...

# %%
data.isnull().sum()
# Out:
# Id                 0
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       1
# dtype: int64

# %%
# Dropping out the null values
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Id                 0
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       0
# dtype: int64

# %%
# Dropping out features like id,groupid,matchid as these according to me 100% doesnt affect the outcome
data = data.drop(['Id','groupId','matchId','matchDuration'],axis=1)
data.head()
# Out:
#    assists  boosts  damageDealt  DBNOs  headshotKills  heals  killPlace  \
# 0        0       0         0.00      0              0      0         60
# 1        0       0        91.47      0              0      0         57
# 2        1       0        68.00      0              0      0         47
# 3        0       0        32.90      0              0      0         75
# 4        0       0       100.00      0              0      0         45
#
#    killPoints  kills  killStreaks  ...  revives rideDistance  roadKills  \
# 0        1241      0            0  ...        0       0.0000          0
# 1           0      0            0  ...        0       0.0045          0
# 2           0      0            0  ...        0       0.0000          0
# 3           0      0            0  ...        0       0.0000          0
# 4           0      1            1  ...        0       0.0000          0
#
#    swimDistance  teamKills  vehicleDestroys  walkDistance  weaponsAcquired  \
# ...

# %%
data.describe()
# Out:
#             assists        boosts   damageDealt         DBNOs  headshotKills  \
# count  4.446965e+06  4.446965e+06  4.446965e+06  4.446965e+06   4.446965e+06
# mean   2.338150e-01  1.106908e+00  1.307172e+02  6.578757e-01   2.268196e-01
# std    5.885731e-01  1.715794e+00  1.707806e+02  1.145743e+00   6.021553e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 50%    0.000000e+00  0.000000e+00  8.424000e+01  0.000000e+00   0.000000e+00
# 75%    0.000000e+00  2.000000e+00  1.860000e+02  1.000000e+00   0.000000e+00
# max    2.200000e+01  3.300000e+01  6.616000e+03  5.300000e+01   6.400000e+01
#
#               heals     killPlace    killPoints         kills   killStreaks  \
# count  4.446965e+06  4.446965e+06  4.446965e+06  4.446965e+06  4.446965e+06
# mean   1.370148e+00  4.759936e+01  5.050062e+02  9.247835e-01  5.439553e-01
# ...

# %% [markdown]
# # EDA

# %%
# %matplotlib inline

# %%
sns.lmplot(x="winPlacePerc",y="kills",data=data)
plt.show()
# In general more kills more winperc although there are chances where you dont kill and win bcuz of ur team mate

# %%
sns.lmplot(x="winPlacePerc",y="damageDealt",data=data)
plt.show()
#Same thing with damagedealt...more damagae dealt more the win perc in general but plot shows eventhough damage perc is zero win perc is considerably high

# %%
sns.lmplot(x="winPlacePerc",y="walkDistance",data=data)
plt.show()
#lot of winner without even walking...maybe due to strong team-mates or they have hacked the game

# %%
sns.lmplot(x="winPlacePerc",y="swimDistance",data=data)
plt.show()
#not much insights

# %%
sns.lmplot(x="winPlacePerc",y="rideDistance",data=data)
plt.show()
#not much insights

# %%
sns.lmplot(x="winPlacePerc",y="winPoints",data=data)
plt.show()
#doesnt make much sense

# %%
sns.lmplot(x="winPlacePerc",y="killPoints",data=data)
plt.show()
#same as above

# %%
sns.lmplot(x="winPlacePerc",y="killStreaks",data=data)
plt.show()

# %%
sns.set(rc = {'figure.figsize':(20,20)})
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Insights :
# ->Killpoints and winpoints is highly correlated(corr coefficient 0.98)
# ->kills and damage dealt is correlated decently (corr coeff 0.89)
# ->kills and killstreak is correlated decntly(corr coeff 0.8)
# ->Kills and walkdistance is correlated (corr coeff 0.81)
# ->Rankpoint and winpoints are highly negatively related to each other but have have little or no relation with winperc...hence we could drop winpoints killpoint rankpoints

# %%
data = data.drop(['rankPoints','winPoints','killPoints'],axis=1)

# %%
sns.lmplot(x="winPlacePerc",y="heals",data=data)
plt.show()

# %%
data.head()
# Out:
#    assists  boosts  damageDealt  DBNOs  headshotKills  heals  killPlace  \
# 0        0       0         0.00      0              0      0         60
# 1        0       0        91.47      0              0      0         57
# 2        1       0        68.00      0              0      0         47
# 3        0       0        32.90      0              0      0         75
# 4        0       0       100.00      0              0      0         45
#
#    kills  killStreaks  longestKill  ... numGroups  revives  rideDistance  \
# 0      0            0         0.00  ...        26        0        0.0000
# 1      0            0         0.00  ...        25        0        0.0045
# 2      0            0         0.00  ...        47        0        0.0000
# 3      0            0         0.00  ...        30        0        0.0000
# 4      1            1        58.53  ...        95        0        0.0000
#
#    roadKills  swimDistance  teamKills  vehicleDestroys  walkDistance  \
# ...
